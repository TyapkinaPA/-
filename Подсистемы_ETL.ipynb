# %% [markdown]
# <a href="https://colab.research.google.com/github/TyapkinaPA/-/blob/main/%D0%9F%D0%BE%D0%B4%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC%D1%8B_ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Data gird
# позволяет ввести статический список строк в таблице. Обычно это делается в тестовых, справочных или демонстрационных целях.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Get system info
# генерируется одна строка с полями, содержащими запрошенную информацию. Также принимаются входные строки. Выбранные значения добавляются к строкам, найденным во входном потоке (-ах).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## JSON input
# извлекаются соответствующие части из структур JSON, файлов или входящих полей и выводятся строки.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Calculator
# предоставляет вам предопределенные функции, которые могут быть выполнены для значений полей ввода. Если вам нужны другие общие, часто используемые функции, посетите страницу сообщества Pentaho и сообщите Pentaho о вашем запросе на улучшение.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SQL file output
# входные данные записываются в текстовый файл в виде набора инструкций SQL. SQL генерируется на диалекте выбранной базы данных.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Text file output
# используется для экспорта данных в формат текстового файла. Это обычно используется для генерации значений, разделенных запятыми (CSV-файлы), которые могут быть прочитаны приложениями для работы с электронными таблицами. Также можно создавать файлы фиксированной ширины, задавая длины в полях на вкладке поля.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Table output
# позволяет загружать данные в таблицу базы данных. Вывод таблицы эквивалентен оператору DML INSERT. Этот шаг предоставляет параметры конфигурации для целевой таблицы и множество опций, связанных с обслуживанием и/или производительностью, таких как размер фиксации и использование пакетного обновления для вставок.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Write to log
# записывает информацию в систему ведения журнала PDI (Pentaho Data Integration).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Microsoft Excel input
# предоставляет вам возможность считывать данные из одного или нескольких файлов Excel и OpenOffice. В следующих разделах описаны все доступные функции для настройки этапа ввода в Excel.
